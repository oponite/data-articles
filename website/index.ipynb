# %% [markdown]
# ---
# toc: false
# title: ""
# ---

# %% [markdown]
# ## Welcome to `data-articles`!

# %% [markdown]
# This website is a collection of articles about mathematics, sports, and finance, written in English and Python notebooks.

# %% [markdown]
# ### About Me

# %% [markdown]
# My name is `oponite`.
#
# I have a tendency to see the world through numbers. Nothing fascinates me more than when numbers tell unexpected narratives about the happenings of the world.
#
# This website is an attempt to share those stories.
